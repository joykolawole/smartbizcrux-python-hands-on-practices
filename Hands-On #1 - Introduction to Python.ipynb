# %%
print("My name is Joy")
print("I am learning Python")
print("Programming is exciting!")
# Out:
# My name is Joy
# I am learning Python
# Programming is exciting!

# %%
print("My favorite food is Rice.")
print ("my favorite Movie is nollywood")
print("my favorite color is red")
# Out:
# My favorite food is Rice.
# my favorite Movie is nollywood
# my favorite color is red

# %%
print(15 + 5)
# Out:
# 20

# %%
print(72 / 9)
print(18 % 5)
print(10 // 3)
print(5**2)
# Out:
# 8.0
# 3
# 3
# 25

# %%
# Display programming language
print("Python")
print("Programming")
print("Lesson One")
# Out:
# Python
# Programming
# Lesson One
