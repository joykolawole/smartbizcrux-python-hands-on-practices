# %%
username_correct = False
password_correct = True
account_locked = False
if username_correct and password_correct and not account_locked:
   print("access granted")
else:
   print("access denied")
# Out:
# access denied

# %%
score = 85
participated = True
low_income = False
if score > 80 and (participated or low_income):
   print("Congratulations! Scholarship Approved.")
else:
   print("Scholarship Not Approved.")
# Out:
# Congratulations! Scholarship Approved.

# %%
#Smart Server Health Monitor

cpu_usage = 75
memory_usage = 92
disk_usage = 60
if cpu_usage>90 or memory_usage>90 or disk_usage>95:
   print("⚠️ Critical Alert!")
else:
   print("✅ System Healthy")
# Out:
# ⚠️ Critical Alert!

# %%
#Study Buddy Bonus Challenge (Optional)


logged_in = True
item_in_stock = True
payment_method = True
wallet_balance = False
account = False
if logged_in and item_in_stock and payment_method or wallet_balance and not account:
    print("✅ Order Confirmed")
else:
    print("❌ Order Failed")
# Out:
# ✅ Order Confirmed
