# %% [markdown]
# # Lesson 5B Python Solutions

# %%
# Exercise 1
student_name="Esther Johnson"
age=17
subject="Mathematics"
score=91.75

print(f"""==============================
STUDENT REPORT
==============================
Student : {student_name}
Age : {age} years
Subject : {subject}
Score : {score:.2f}%

Congratulations {student_name}!
You passed {subject}.
==============================""")

# Exercise 2
employee_name="David Musa"
department="Finance"
basic_salary=185000
bonus=35000
tax_rate=0.075

gross_salary=basic_salary+bonus
tax_amount=gross_salary*tax_rate
net_salary=gross_salary-tax_amount

print(f"""\n==================================
PAYROLL SUMMARY
==================================
Employee : {employee_name}
Department : {department}
Basic Salary : ₦{basic_salary:,.2f}
Bonus : ₦{bonus:,.2f}
Gross Salary : ₦{gross_salary:,.2f}
Tax (7.5%) : ₦{tax_amount:,.2f}
Net Salary : ₦{net_salary:,.2f}
==================================""")

# Exercise 3
customer_name="Amina Bello"
product="Wireless Headphones"
quantity=3
unit_price=27500

total_cost=quantity*unit_price
discount=total_cost*0.10 if quantity>2 else 0
final_amount=total_cost-discount

print(f"""\n====================================
ONLINE STORE RECEIPT
====================================
Customer : {customer_name}
Product : {product}
Quantity : {quantity}
Unit Price : ₦{unit_price:,.2f}
Total Cost : ₦{total_cost:,.2f}
Discount : ₦{discount:,.2f}
Final Amount : ₦{final_amount:,.2f}
Thank you for shopping with us!
====================================""")

# Bonus Case Study
employee_id="EMP1024"
employee_name="Timothy Analytics"
department="Data Analytics"
position="Data Analyst"
experience=5
monthly_salary=550000
performance_rating="Excellent"

annual_salary=monthly_salary*12
annual_bonus=annual_salary*0.05
status="Eligible for Promotion" if performance_rating=="Excellent" else "Outstanding Contribution" if performance_rating=="Very Good" else "Keep Improving" if performance_rating=="Good" else "Performance Review Required"

print(f"""\n==================================================
SMARTBIZCRUX DATA SOLUTIONS
EMPLOYEE PROFILE
==================================================
Employee ID : {employee_id}
Employee Name : {employee_name}
Department : {department}
Position : {position}
Experience : {experience} Years
Monthly Salary : ₦{monthly_salary:,.2f}
Performance Rating : {performance_rating}
Annual Salary : ₦{annual_salary:,.2f}
Annual Bonus (5%) : ₦{annual_bonus:,.2f}
Performance Status : {status}
==================================================
Employee {employee_name} is currently working as a {position} in the {department} department.
Based on the current salary of ₦{monthly_salary:,.2f} per month, the annual salary is ₦{monthly_salary*12:,.2f}.
==================================================""")
