# %%
#Exercise 1: Creating Variables

name = "joy"
age = "21"
country = "nigeria"
print("name:",  name, "age:",  age, "country:",  country)
# Out:
# name: joy age: 21 country: nigeria

# %%
#Exercise 2: Salary Calculation

employee_salary = 180000
employee_bonus = 35000
total_salary = employee_salary + employee_bonus
print(total_salary)
# Out:
# 215000

# %%
#Exercise 3: User Input

name = input("enter your name:")
programming_language = input("enter your Favourite Programming Language:")
print("hello",  name,  "your favourite programming language is",  programming_language)
# Out:
# enter your name: joy
# enter your Favourite Programming Language: python
# hello joy your favourite programming language is python

# %%
#Exercise 4: Working with Data Types

x = 10
y = 3.4
name = "joy"
is_valid = (x==10)
print(type(x))
print(type(y))
print(type(name))
print(type(is_valid))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
#Exercise 5: Dynamic Typing

x = 10
print(type(x))
x = "you"
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#Mini Project: Student Information Card

     STUDENT INFORMATION CARD


Name = input("enter your name")
Age = input("enter you age")
Course = input("which course interest you")
Country = input("your country")
print("name:",  Name)
print("age:",  Age)
print("course:",  Course)
print("country:",  Country)

     Data Types


print ("name:", type(Name))
print ("age:", type(Age))
print ("course:", type(Course))
print ("country:", type(Country))

# %%
#Bonus Challenge ⭐
Age = input("enter you age")
print("age:", type(age))

#After Conversion
Age = int(Age)
print("age:", type(Age))
print("Your age has been converted to an integer")
# Out:
# enter you age 21
# age: <class 'str'>
# age: <class 'int'>
# Your age has been converted to an integer
